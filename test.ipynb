# %%
class MyConfigurableClass:
    def __init__(self, **kwargs):
        self.opt = {"Name": "Brian", "Age": 16}
        self.opt.update(kwargs)

a = MyConfigurableClass(Name = "Br")

print(a.opt)
# Out:
# {'Name': 'Br', 'Age': 16}
